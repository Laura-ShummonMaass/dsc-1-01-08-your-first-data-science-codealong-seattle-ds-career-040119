# %% [markdown]
# # Your First Data Science Codealong!
#
# ## Introduction
#
# In this codealong, you'll get to do your first taste of a real data science workflow! You'll use Jupyter Notebook to import pre-written libraries, import data into your notebook from a Comma Seperated Values file (a .csv file) and you'll even get to create some plots!
#
# Don't worry if it feels like a lot or you get confused on this codealogn. Our goal here is just to give you a taste of what you'll be able to do as a data scientist, and afterwards, we'll go back and re-introduce all of the concepts that we skimmed over this time through, so by the end of the section you should have a much stronger understanding of this - even if you have no previous experience of programming.
#
# Don't worry about running tests for this notebook. Just take your time to explore the data and the code.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Code along (following detailed instructions) to import a csv file and then plot the data

# %% [markdown]
# ## Jupyter Notebook and Running Cells
#
# **Welcome to programming!**
# Juptyer Notebooks (historically called IPythonNotebooks) will be our primary tool when conducting data science. The first thing to know with this is that each cell block [of code] can be run be pressing **shift+enter**. Try running the below code block:

# %%
print('This is code being run.')
# Out:
# This is code being run.

# %% [markdown]
# ## Importing Packages
# The next thing we're going to do is load in some python packages that will be part of our toolbox for manipulating and analyzing data. The standard python package for working with data tables is called **pandas**. Below, we import this under the **alias** pd, which is the industry standard. This will give us a shorthand way to access special functions and methods within the package without having to type the longer name pandas.
#
# * Again, press **shift+enter** to run the code below

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Jupyter Notebook Cell Types
#
# You might have started to notice that the code blocks have little notes that say **In [ ]:** before you run them, and then are filled with a number after you run them. This is important, as it tells you what order cell blocks were run. (Which can sometimes affect how a program runs.)
#
# You may also notice that other cell blocks, such as this one, do not have the **In [ ]:** label as with the code blocks. This is because this cell block is formatted as **Markdown** rather then code. You can see (and change) what type of cell is by clicking the dropdown menu at the top:
# <img src="Jupyter_Notebook_Cell_Type_Dropdown.png" width=600>

# %% [markdown]
# # Command Versus Edit Mode
#
# You should also start to notice that when you are in a cell writing code (or notes), the cell is highlighted in **green** meaning you are in **edit mode**.
#
# Alternatively, if you **press esc**, the cursor will be in **blue** inidicating that you are in **command mode**.
#
# ### Edit Mode
# Edit mode is the standard mode for editing cells, whether its writing code or notes.
# To enter edit mode from command mode simply hit enter, or double click on a cell.
#
# ### Command Mode
# In command mode, you can delete cells, add cells, copy cells, paste cells, change cell types, and more. You can also do these tasks in a more cumbersome (and time consuming) manner by using the various headers in the menu bar at top.
# <img src="Jupyter_Menu.png" width=600>
# You can also see a full list of shortcuts available in command and edit mode under the help menu.
#
# <img src="Jupyter_Help_Menu.png" width=600>

# %% [markdown]
# # Running Bash Commands
#
# We can also run bash commands just as we did before from the terminal directly within iPython notebooks!
#  (Note: bash commands cannot be mixed with python and must be in their own cell block.)
#
# Try it out!

# %%
pwd
# Out:
# '/home/laura/dsc-1-01-08-your-first-data-science-codealong-seattle-ds-career-040119'

# %%
ls
# Out:
# CONTRIBUTING.md                          lego_sets.csv*
# docstring.png                            LICENSE.md
# docstring_preview.png                    pd_methods.png
# index_files/                             pd_read_methods.png
# index.ipynb                              python_built_in_functions.png
# Jupyter_Help_Menu.png                    README.md
# Jupyter_Menu.png                         string-slicing.png
# Jupyter_Notebook_Cell_Type_Dropdown.png

# %% [markdown]
# ## Loading a DataFrame
# The primary datatype within the pandas package is called a dataframe and is similar to a spreadsheet in excel. Here's a brief example of loading a csv file from your hard drive:

# %%
df = pd.read_csv('lego_sets.csv') #Loads the dataframe in
print(len(df)) #Prints the length of the dataframe
df.tail() #Uses a built in method common to all Pandas Dataframes
# Out:
# 12261
#        ages  list_price  num_reviews  piece_count  play_star_rating  \
# 12256  7-14     36.5878          6.0        341.0               4.4
# 12257  7-14     24.3878          8.0        217.0               4.1
# 12258  7-14     24.3878         18.0        233.0               4.6
# 12259  6-14     12.1878          1.0         48.0               5.0
# 12260  6-14     12.1878         11.0        109.0               4.5
#
#                                                prod_desc  prod_id  \
# 12256  Protect NINJAGO® City from flying Manta Ray Bo...  70609.0
# 12257         Stop a Piranha Attack with Kai and Misako!  70629.0
# 12258   Stop a crime in the NINJAGO® City street market!  70607.0
# 12259  Achieve Spinjitzu greatness with the Green Ninja!  70628.0
# 12260  Practice your Spinjitzu skills with Kai and Zane!  70606.0
#
#                                           prod_long_desc review_difficulty  \
# 12256  Help Cole save Shen-Li in this cool THE LEGO® ...              Easy
# 12257  Play out an action-packed Piranha Mech pursuit...              Easy
# 12258  Team up with Lloyd Garmadon, Nya and Officer T...              Easy
# 12259  Learn all the skills of Spinjitzu with THE LEG...         Very Easy
# 12260  Join the ninja heroes at the dojo with this ac...              Easy
#
#                        set_name  star_rating                 theme_name  \
# 12256          Manta Ray Bomber          4.3  THE LEGO® NINJAGO® MOVIE™
# 12257            Piranha Attack          3.6  THE LEGO® NINJAGO® MOVIE™
# 12258       NINJAGO® City Chase          4.6  THE LEGO® NINJAGO® MOVIE™
# 12259  Lloyd - Spinjitzu Master          5.0  THE LEGO® NINJAGO® MOVIE™
# 12260        Spinjitzu Training          4.7  THE LEGO® NINJAGO® MOVIE™
#
#        val_star_rating country
# 12256              4.2      PT
# 12257              4.1      PT
# 12258              4.5      PT
# 12259              5.0      PT
# 12260              4.8      PT

# %% [markdown]
# # Python Comments
#
# Note the green text following the **#**.
# Anything following a **#** in python is a comment and will not actually execute.
# This is a useful feature for annotating your code with notes for yourself and other later so that your code is easy to read.

# %% [markdown]
# # Accessing Methods from Packages and Objects
#
# A little more theory and context:
#
# When we loaded in packages on our first cell block (import pandas as pd), we loaded code into memory. That code included functions, variables and other objects. Collectively, all of these items is loaded under the package name or alias.
#
# We demonstrated this when we used the **pd.read_csv()** method above.
#
# This also demonstrates the **dot notation** in python, which is how we access built in methods or attriubtes of a given object. Similar to what we saw with bash in the command line, we can also use **tab completion** to preview methods available in packages or other objects.
#
# ### Try this out yourself
#
# * In the cell below, navigate your cursor to the right of **pd.**
# * Press tab to see a list of available methods/attributes
#
# <img src="pd_methods.png" width=600>

# %%
pd.read_csv
# Out:
# <function pandas.io.parsers._make_parser_function.<locals>.parser_f(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, doublequote=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)>

# %% [markdown]
# You can also start typing to subset the list of available commands:
# <img src="pd_read_methods.png" width=600>

# %% [markdown]
# # Pulling up Docstrings
#
# Even better, you can even see how a method works by pulling up its **docstring**!
# You can do this by writing **?** after the method and running the cell.
#
# <img src="docstring.png" width=500>
#
#
# Try it out!

# %%
pd.read_csv?

# %% [markdown]
# Alternatively, you can pull up a preview of the docstring by pressing **shift+tab within the parentheses of a method**
# <img src="docstring_preview.png" width=500>

# %%
pd.read_csv() #Move your cursor inside the parentheses and press shift+tab
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-7-59ba97e74ff2> in <module>()
# ----> 1 pd.read_csv() #Move your cursor inside the parentheses and press shift+tab
#
# TypeError: parser_f() missing 1 required positional argument: 'filepath_or_buffer'

# %% [markdown]
# # Variables
#
# The other thing that happened in our block of code above was that we defined a **variable**.
#
# This happened in the first line of code:
# ```df = pd.read_csv('lego_sets.csv')```
#
# As we saw, we used the built in *read_csv* method from the *pandas* package which we imported under the *alias* *pd*.
#
# The output of this method was then assigned to the variable *df*. This is the standard syntax for declaring any variable. You do not have to specify variable types, as in many other programming languages. Simply:
#
# `variable_name = what_to_stor_in_the_variable`

# %% [markdown]
# # Built in Python Functions
#
# We also used two built in python functions:
#     * len() #Returns the lenght of an object
#     * print() #Prints stuff!
# In general, **python has reserved keywords** for built in functions like this.
# **Be sure to not name your variables any of these!**
#
# <img src="python_built_in_functions.png" width=600>

# %% [markdown]
# You can also check what type of object something is using the built in **type()** method. This can be useful when determining how to work with an object that you are unfamiliar with.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Common DataFrame Methods
# As you can see, our variable **df** is a DataFrame object (which is part of the Pandas core package). Here's some other common methods you will want to become familiar with when working with Pandas dataframes:
# * df.head()
#     * Preview the first 5 rows of a dataframe. Pass a number for more/less rows
# * df.tail(10)
#     * Preview last 10 rows (default 5 if no number given)
# * df.info()
#     * Returns column names and details about each column
# * df.columns
#     * Return column names. Note that there is no parentheses for this. This is becuase this is an attribute as opposed to a method

# %%
min(df['piece_count'])
# Out:
# 1.0

# %%
dict(df)
# Out:
# {'ages': 0        6-12
#  1        6-12
#  2        6-12
#  3         12+
#  4         12+
#  5         12+
#  6         12+
#  7         12+
#  8         12+
#  9         12+
#  10        12+
#  11        12+
#  12        12+
#  13       7-12
#  14        10+
#  15        10+
#  16        10+
#  17        10+
#  18        10+
#  19        10+
#  20        10+
#  21        10+
#  22        10+
#  23        10+
#  24        10+
#  25        10+
#  26        10+
#  27        10+
#  28        10+
#  29        10+
#           ...
#  12231    7-14
#  12232    7-14
#  12233    8-14
#  12234    7-14
#  12235    7-14
#  12236    7-14
#  12237    7-14
#  12238    6-12
#  12239    6-12
#  12240      5+
#  12241    8-14
#  12242     16+
#  12243    9-14
#  12244    9-14
#  12245    9-14
#  12246    9-14
#  12247    9-14
#  12248    9-14
#  12249    9-14
#  12250    8-14
#  12251    8-14
#  12252    8-14
#  12253    8-14
#  12254    7-14
#  12255    8-14
#  12256    7-14
#  12257    7-14
#  12258    7-14
#  12259    6-14
#  12260    6-14
#  Name: ages, Length: 12261, dtype: object, 'list_price': 0         29.9900
#  1         19.9900
#  2         12.9900
#  3         99.9900
#  4         79.9900
#  5         59.9900
#  6         59.9900
#  7         49.9900
#  8         39.9900
#  9         39.9900
#  10        39.9900
#  11        34.9900
#  12        29.9900
#  13       159.9900
#  14        29.9900
#  15        19.9900
#  16        19.9900
#  17         9.9900
#  18         9.9900
#  19         9.9900
#  20         9.9900
#  21         9.9900
#  22         9.9900
#  23         9.9900
#  24         9.9900
#  25         9.9900
#  26         9.9900
#  27         9.9900
#  28         9.9900
#  29         9.9900
#             ...
#  12231     48.7878
#  12232     48.7878
#  12233     42.6878
#  12234     42.6878
#  12235     30.4878
#  12236     30.4878
#  12237     30.4878
#  12238     18.2878
#  12239     18.2878
#  12240      4.8678
#  12241    103.6878
#  12242    365.9878
#  12243    225.6878
#  12244    134.1878
#  12245    103.6878
#  12246    103.6878
#  12247     97.5878
#  12248     97.5878
#  12249     82.9478
#  12250     73.1878
#  12251     60.9878
#  12252     60.9878
#  12253     48.7878
#  12254     36.5878
#  12255     36.5878
#  12256     36.5878
#  12257     24.3878
#  12258     24.3878
#  12259     12.1878
#  12260     12.1878
#  Name: list_price, Length: 12261, dtype: float64, 'num_reviews': 0         2.0
#  1         2.0
#  2        11.0
#  3        23.0
#  4        14.0
#  5         7.0
#  6        37.0
#  7        24.0
#  8        23.0
#  9        11.0
#  10       14.0
#  11       53.0
#  12        7.0
#  13       63.0
#  14       13.0
#  15        1.0
#  16        1.0
#  17        1.0
#  18        1.0
#  19        3.0
#  20        2.0
#  21        1.0
#  22        1.0
#  23        2.0
#  24        7.0
#  25        5.0
#  26        3.0
#  27        5.0
#  28        3.0
#  29        1.0
#           ...
#  12231     5.0
#  12232    12.0
#  12233    24.0
#  12234    18.0
#  12235     2.0
#  12236     8.0
#  12237    19.0
#  12238     7.0
#  12239    18.0
#  12240    13.0
#  12241     9.0
#  12242    88.0
#  12243    52.0
#  12244    15.0
#  12245     9.0
#  12246    11.0
#  12247     6.0
#  12248    19.0
#  12249     8.0
#  12250     8.0
#  12251     7.0
#  12252    29.0
#  12253    21.0
#  12254    10.0
#  12255     8.0
#  12256     6.0
#  12257     8.0
#  12258    18.0
#  12259     1.0
#  12260    11.0
#  Name: num_reviews, Length: 12261, dtype: float64, 'piece_count': 0         277.0
#  1         168.0
#  2          74.0
#  3        1032.0
#  4         744.0
#  5         597.0
#  6         598.0
#  7         780.0
#  8         468.0
#  9         444.0
#  10        386.0
#  11        321.0
#  12        361.0
#  13        847.0
#  14        708.0
#  15        234.0
#  16        160.0
#  17        149.0
#  18        141.0
#  19        101.0
#  20        105.0
#  21        113.0
#  22        136.0
#  23         91.0
#  24        140.0
#  25        143.0
#  26        122.0
#  27        130.0
#  28        119.0
#  29        135.0
#            ...
#  12231     267.0
#  12232     293.0
#  12233     305.0
#  12234     254.0
#  12235     198.0
#  12236     204.0
#  12237     201.0
#  12238     141.0
#  12239     124.0
#  12240       8.0
#  12241     643.0
#  12242    4867.0
#  12243    2295.0
#  12244    1403.0
#  12245     830.0
#  12246    1202.0
#  12247     914.0
#  12248     944.0
#  12249     876.0
#  12250     747.0
#  12251     521.0
#  12252     544.0
#  12253     494.0
#  12254     312.0
#  12255     341.0
#  12256     341.0
#  12257     217.0
#  12258     233.0
#  12259      48.0
#  12260     109.0
#  Name: piece_count, Length: 12261, dtype: float64, 'play_star_rating': 0        4.0
#  1        4.0
#  2        4.3
#  3        3.6
#  4        3.2
#  5        3.7
#  6        3.7
#  7        4.4
#  8        3.6
#  9        3.6
#  10       4.1
#  11       3.2
#  12       4.2
#  13       3.8
#  14       4.7
#  15       3.0
#  16       5.0
#  17       2.0
#  18       2.0
#  19       4.0
#  20       3.0
#  21       5.0
#  22       NaN
#  23       3.0
#  24       3.2
#  25       4.6
#  26       2.7
#  27       4.3
#  28       4.5
#  29       1.0
#          ...
#  12231    3.6
#  12232    4.9
#  12233    4.5
#  12234    4.2
#  12235    4.0
#  12236    4.1
#  12237    4.1
#  12238    4.0
#  12239    4.5
#  12240    4.3
#  12241    4.4
#  12242    4.8
#  12243    4.7
#  12244    4.5
#  12245    4.6
#  12246    4.7
#  12247    4.8
#  12248    3.6
#  12249    4.7
#  12250    4.3
#  12251    4.7
#  12252    4.6
#  12253    4.6
#  12254    3.5
#  12255    4.2
#  12256    4.4
#  12257    4.1
#  12258    4.6
#  12259    5.0
#  12260    4.5
#  Name: play_star_rating, Length: 12261, dtype: float64, 'prod_desc': 0        Catapult into action and take back the eggs fr...
#  1        Launch a flying attack and rescue the eggs fro...
#  2        Chase the piggy with lightning-fast Chuck and ...
#  3        Explore the architecture of the United States ...
#  4        Recreate the Solomon R. Guggenheim Museum® wit...
#  5        Celebrate Shanghai with this LEGO® Architectur...
#  6        Celebrate New York City with this LEGO® Archit...
#  7        Recreate Buckingham Palace with LEGO® Architec...
#  8        Celebrate London with this LEGO® Architecture ...
#  9        Celebrate Chicago with this LEGO® Architecture...
#  10         Experience the grandeur of the Arc de Triomphe!
#  11       Build your own LEGO® interpretation of the ico...
#  12       Celebrate Sydney with this LEGO® Architecture ...
#  13                     Bring your LEGO® creations to life!
#  14           Build a LEGO® BrickHeadz version of yourself!
#  15       Train a raptor with LEGO® BrickHeadz™ Owen and...
#  16       Join Mr. Incredible and Frozone for LEGO® Bric...
#  17       Growl like a Wookiee with a LEGO® BrickHeadz™ ...
#  18       Be a rogue with a LEGO® BrickHeadz™ constructi...
#  19       Save the universe with LEGO® BrickHeadz Iron M...
#  20       Feel the power of Infinity with LEGO® BrickHea...
#  21       Be a legendary outlaw with LEGO® BrickHeadz St...
#  22       Master the skills of a green-skinned assassin ...
#  23       Join the Resistance with a LEGO® BrickHeadz co...
#  24       Say “I love you” with a LEGO® BrickHeadz™ Vale...
#  25         Stand tall with LEGO® BrickHeadz Wonder Woman™!
#  26       Live life in the fast lane with LEGO® BrickHea...
#  27       Summon the dark side with a LEGO® BrickHeadz c...
#  28       Feel the Force with a LEGO® BrickHeadz constru...
#  29                 Dive in with LEGO® BrickHeadz Aquaman™!
#                                 ...
#  12231                 Party on with Superman™ and friends!
#  12232                Join Batman™ in a comical food fight!
#  12233    Put the heat on The Penguin™ Arctic Roller wit...
#  12234    Battle with Batman™ against The Riddler™ and h...
#  12235    Bring down Captain Boomerang™ with Batman’s Ba...
#  12236    Help Batman™ to stop Scarecrow™ delivering a s...
#  12237    Protect the power plant from Mr. Freeze’s ice ...
#  12238    Power into the sky to stop Scarecrow’s fear ga...
#  12239               Help Batman™ stop The Joker™ escaping!
#  12240    Discover new heroes and villains in LEGO® Mini...
#  12241             Launch a space mission from the Batcave!
#  12242           Live the life of a ninja in NINJAGO® City!
#  12243              Join the ninja aboard Wu’s flying ship!
#  12244                   Evade the traps inside the Temple!
#  12245    Defend NINJAGO® City from Garmadon Shark Mech ...
#  12246     Turn sound into a weapon with Cole’s Quake Mech!
#  12247         Take on the shark army with Zane’s Ice Tank!
#  12248    Put the heat on the shark army with Kai’s Fire...
#  12249        Speed to the rescue with Jay’s Lightning Jet!
#  12250        Defend NINJAGO® City against Garma Mecha Man!
#  12251         Get all fired up at Garmadon’s Volcano Lair!
#  12252    Take on Garmadon with the Green Ninja Mech Dra...
#  12253    Smash the shark army out of the water with the...
#  12254    Battle against evil Jungle Garmadon on the jun...
#  12255    Take on the tentacular Flying Jelly Sub with Jay!
#  12256    Protect NINJAGO® City from flying Manta Ray Bo...
#  12257           Stop a Piranha Attack with Kai and Misako!
#  12258     Stop a crime in the NINJAGO® City street market!
#  12259    Achieve Spinjitzu greatness with the Green Ninja!
#  12260    Practice your Spinjitzu skills with Kai and Zane!
#  Name: prod_desc, Length: 12261, dtype: object, 'prod_id': 0        75823.0
#  1        75822.0
#  2        75821.0
#  3        21030.0
#  4        21035.0
#  5        21039.0
#  6        21028.0
#  7        21029.0
#  8        21034.0
#  9        21033.0
#  10       21036.0
#  11       21019.0
#  12       21032.0
#  13       17101.0
#  14       41597.0
#  15       41614.0
#  16       41613.0
#  17       41609.0
#  18       41608.0
#  19       41604.0
#  20       41605.0
#  21       41606.0
#  22       41607.0
#  23       41485.0
#  24       40270.0
#  25       41599.0
#  26       41598.0
#  27       41603.0
#  28       41602.0
#  29       41600.0
#            ...
#  12231    70919.0
#  12232    70920.0
#  12233    70911.0
#  12234    70903.0
#  12235    70918.0
#  12236    70910.0
#  12237    70901.0
#  12238    70913.0
#  12239    70900.0
#  12240    71020.0
#  12241    70923.0
#  12242    70620.0
#  12243    70618.0
#  12244    70617.0
#  12245    70656.0
#  12246    70632.0
#  12247    70616.0
#  12248    70615.0
#  12249    70614.0
#  12250    70613.0
#  12251    70631.0
#  12252    70612.0
#  12253    70611.0
#  12254    70608.0
#  12255    70610.0
#  12256    70609.0
#  12257    70629.0
#  12258    70607.0
#  12259    70628.0
#  12260    70606.0
#  Name: prod_id, Length: 12261, dtype: float64, 'prod_long_desc': 0        Use the staircase catapult to launch Red into ...
#  1        Pilot Pig has taken off from Bird Island with ...
#  2        Pitch speedy bird Chuck against the Piggy Car....
#  3        Discover the architectural secrets of the icon...
#  4        Discover the architectural secrets of Frank Ll...
#  5        Recreate Shanghai in China's blend of historic...
#  6        Celebrate the architectural diversity of New Y...
#  7        Build a LEGO® brick model of London's official...
#  8        Celebrate the architectural diversity of Londo...
#  9        Recreate Chicago’s blend of historical and mod...
#  10       Capture the architectural elegance of one of t...
#  11       Presenting the LEGO® Architecture interpretati...
#  12       Capture the architectural essence and splendor...
#  13       Take your LEGO® play to the next level with th...
#  14       Fuel your creativity by making a LEGO® BrickHe...
#  15       These LEGO® BrickHeadz™ 41614 Owen & Blue cons...
#  16       These LEGO® BrickHeadz™ 41613 Mr. Incredible &...
#  17       This LEGO® BrickHeadz™ 41609 Chewbacca is fun ...
#  18       This LEGO® BrickHeadz™ 41608 Han Solo is fun t...
#  19       This Iron Man MK50 LEGO® BrickHeadz constructi...
#  20       This Thanos LEGO® BrickHeadz construction char...
#  21       This Star-Lord LEGO® BrickHeadz construction c...
#  22       This Gamora LEGO® BrickHeadz construction char...
#  23       This LEGO® BrickHeadz construction character f...
#  24       Build your way to someone’s heart and say “Bee...
#  25       This Wonder Woman™ LEGO® BrickHeadz constructi...
#  26       The Flash™ LEGO® BrickHeadz construction chara...
#  27       This LEGO® BrickHeadz construction character f...
#  28       This LEGO® BrickHeadz construction character f...
#  29       This Aquaman™ LEGO® BrickHeadz construction ch...
#                                 ...
#  12231    Recreate the hilarious scene from THE LEGO® BA...
#  12232    Help Batman™ fend off Egghead™ and Condiment K...
#  12233    Join Batman’s pursuit of The Penguin in THE LE...
#  12234    Take on four Super-Villains at once in THE LEG...
#  12235    Glide over bumps in the Gotham City streets an...
#  12236    Save Gotham City Energy Facility from a fear g...
#  12237    Help Batman™ defend the Gotham City Energy Fac...
#  12238    Team up with Batman™ to stop Scarecrow™ spread...
#  12239    Stage a face-off between The Joker™ and Batman...
#  12240    Bring exciting new play possibilities to exist...
#  12241    Take off from the Batcave in The Bat-Space Shu...
#  12242    Enjoy endless role-play fun in NINJAGO® City, ...
#  12243    Construct Wu’s huge ninja training base, Desti...
#  12244    Join a ninja mission to infiltrate THE LEGO® N...
#  12245    Help Lloyd to save Nomis and Nancy from Garmad...
#  12246    Fire ‘soundwaves’ from Cole’s Quake Mech to sa...
#  12247    Help Zane save Patty Keys and Torben from the ...
#  12248    Get set for sizzling battle action with this h...
#  12249    Save Ed and Edna from the shark army’s crab wi...
#  12250    Help Lloyd protect civilian Pat from attack by...
#  12251    Join Zane’s mission to infiltrate evil Garmado...
#  12252    Outwit The Green Ninja’s evil father Garmadon ...
#  12253    Launch into battle against the shark army and ...
#  12254    Team up with Wu and Kai to take on Jungle Garm...
#  12255    Join ninja Jay in battle against the shark arm...
#  12256    Help Cole save Shen-Li in this cool THE LEGO® ...
#  12257    Play out an action-packed Piranha Mech pursuit...
#  12258    Team up with Lloyd Garmadon, Nya and Officer T...
#  12259    Learn all the skills of Spinjitzu with THE LEG...
#  12260    Join the ninja heroes at the dojo with this ac...
#  Name: prod_long_desc, Length: 12261, dtype: object, 'review_difficulty': 0            Average
#  1               Easy
#  2               Easy
#  3            Average
#  4        Challenging
#  5            Average
#  6            Average
#  7            Average
#  8            Average
#  9            Average
#  10           Average
#  11           Average
#  12              Easy
#  13           Average
#  14           Average
#  15              Easy
#  16         Very Easy
#  17         Very Easy
#  18         Very Easy
#  19           Average
#  20              Easy
#  21              Easy
#  22               NaN
#  23              Easy
#  24              Easy
#  25              Easy
#  26         Very Easy
#  27              Easy
#  28              Easy
#  29         Very Easy
#              ...
#  12231           Easy
#  12232        Average
#  12233           Easy
#  12234           Easy
#  12235            NaN
#  12236        Average
#  12237           Easy
#  12238           Easy
#  12239           Easy
#  12240      Very Easy
#  12241        Average
#  12242    Challenging
#  12243    Challenging
#  12244        Average
#  12245        Average
#  12246        Average
#  12247        Average
#  12248        Average
#  12249        Average
#  12250        Average
#  12251        Average
#  12252        Average
#  12253        Average
#  12254           Easy
#  12255        Average
#  12256           Easy
#  12257           Easy
#  12258           Easy
#  12259      Very Easy
#  12260           Easy
#  Name: review_difficulty, Length: 12261, dtype: object, 'set_name': 0                         Bird Island Egg Heist
#  1                            Piggy Plane Attack
#  2                              Piggy Car Escape
#  3                United States Capitol Building
#  4                 Solomon R. Guggenheim Museum®
#  5                                      Shanghai
#  6                                 New York City
#  7                             Buckingham Palace
#  8                                        London
#  9                                       Chicago
#  10                              Arc de Triomphe
#  11                             The Eiffel Tower
#  12                                       Sydney
#  13                       BOOST Creative Toolbox
#  14                                  Go Brick Me
#  15                                  Owen & Blue
#  16                     Mr. Incredible & Frozone
#  17                                   Chewbacca™
#  18                                    Han Solo™
#  19                                Iron Man MK50
#  20                                       Thanos
#  21                                    Star-Lord
#  22                                       Gamora
#  23                                         Finn
#  24                              Valentine's Bee
#  25                                Wonder Woman™
#  26                                   The Flash™
#  27                                    Kylo Ren™
#  28                                          Rey
#  29                                     Aquaman™
#                            ...
#  12231     The Justice League™ Anniversary Party
#  12232                  Egghead™ Mech Food Fight
#  12233                The Penguin™ Arctic Roller
#  12234                 The Riddler™ Riddle Racer
#  12235                        The Bat-Dune Buggy
#  12236               Scarecrow™ Special Delivery
#  12237                    Mr. Freeze™ Ice Attack
#  12238               Scarecrow™ Fearful Face-off
#  12239                 The Joker™ Balloon Escape
#  12240           THE LEGO® BATMAN MOVIE Series 2
#  12241                     The Bat-Space Shuttle
#  12242                             NINJAGO® City
#  12243                          Destiny's Bounty
#  12244    Temple of The Ultimate Ultimate Weapon
#  12245             garmadon, Garmadon, GARMADON!
#  12246                                Quake Mech
#  12247                                  Ice Tank
#  12248                                 Fire Mech
#  12249                             Lightning Jet
#  12250                           Garma Mecha Man
#  12251                   Garmadon's Volcano Lair
#  12252                   Green Ninja Mech Dragon
#  12253                             Water Strider
#  12254                              Master Falls
#  12255                          Flying Jelly Sub
#  12256                          Manta Ray Bomber
#  12257                            Piranha Attack
#  12258                       NINJAGO® City Chase
#  12259                  Lloyd - Spinjitzu Master
#  12260                        Spinjitzu Training
#  Name: set_name, Length: 12261, dtype: object, 'star_rating': 0        4.5
#  1        5.0
#  2        4.3
#  3        4.6
#  4        4.6
#  5        4.9
#  6        4.2
#  7        4.7
#  8        4.7
#  9        4.8
#  10       4.4
#  11       4.6
#  12       4.6
#  13       3.4
#  14       4.8
#  15       5.0
#  16       5.0
#  17       3.0
#  18       4.0
#  19       4.7
#  20       5.0
#  21       5.0
#  22       5.0
#  23       4.5
#  24       4.9
#  25       5.0
#  26       4.0
#  27       5.0
#  28       5.0
#  29       4.0
#          ...
#  12231    3.2
#  12232    4.8
#  12233    4.8
#  12234    4.2
#  12235    4.5
#  12236    4.4
#  12237    4.6
#  12238    4.1
#  12239    4.7
#  12240    4.8
#  12241    4.8
#  12242    4.9
#  12243    4.9
#  12244    4.8
#  12245    4.9
#  12246    4.5
#  12247    4.8
#  12248    4.2
#  12249    5.0
#  12250    4.5
#  12251    4.3
#  12252    4.7
#  12253    4.5
#  12254    4.0
#  12255    4.6
#  12256    4.3
#  12257    3.6
#  12258    4.6
#  12259    5.0
#  12260    4.7
#  Name: star_rating, Length: 12261, dtype: float64, 'theme_name': 0                     Angry Birds™
#  1                     Angry Birds™
#  2                     Angry Birds™
#  3                     Architecture
#  4                     Architecture
#  5                     Architecture
#  6                     Architecture
#  7                     Architecture
#  8                     Architecture
#  9                     Architecture
#  10                    Architecture
#  11                    Architecture
#  12                    Architecture
#  13                           BOOST
#  14                      BrickHeadz
#  15                      BrickHeadz
#  16                      BrickHeadz
#  17                      BrickHeadz
#  18                      BrickHeadz
#  19                      BrickHeadz
#  20                      BrickHeadz
#  21                      BrickHeadz
#  22                      BrickHeadz
#  23                      BrickHeadz
#  24                      BrickHeadz
#  25                      BrickHeadz
#  26                      BrickHeadz
#  27                      BrickHeadz
#  28                      BrickHeadz
#  29                      BrickHeadz
#                     ...
#  12231       THE LEGO® BATMAN MOVIE
#  12232       THE LEGO® BATMAN MOVIE
#  12233       THE LEGO® BATMAN MOVIE
#  12234       THE LEGO® BATMAN MOVIE
#  12235       THE LEGO® BATMAN MOVIE
#  12236       THE LEGO® BATMAN MOVIE
#  12237       THE LEGO® BATMAN MOVIE
#  12238       THE LEGO® BATMAN MOVIE
#  12239       THE LEGO® BATMAN MOVIE
#  12240                  Minifigures
#  12241       THE LEGO® BATMAN MOVIE
#  12242    THE LEGO® NINJAGO® MOVIE™
#  12243    THE LEGO® NINJAGO® MOVIE™
#  12244    THE LEGO® NINJAGO® MOVIE™
#  12245    THE LEGO® NINJAGO® MOVIE™
#  12246    THE LEGO® NINJAGO® MOVIE™
#  12247    THE LEGO® NINJAGO® MOVIE™
#  12248    THE LEGO® NINJAGO® MOVIE™
#  12249    THE LEGO® NINJAGO® MOVIE™
#  12250    THE LEGO® NINJAGO® MOVIE™
#  12251    THE LEGO® NINJAGO® MOVIE™
#  12252    THE LEGO® NINJAGO® MOVIE™
#  12253    THE LEGO® NINJAGO® MOVIE™
#  12254    THE LEGO® NINJAGO® MOVIE™
#  12255    THE LEGO® NINJAGO® MOVIE™
#  12256    THE LEGO® NINJAGO® MOVIE™
#  12257    THE LEGO® NINJAGO® MOVIE™
#  12258    THE LEGO® NINJAGO® MOVIE™
#  12259    THE LEGO® NINJAGO® MOVIE™
#  12260    THE LEGO® NINJAGO® MOVIE™
#  Name: theme_name, Length: 12261, dtype: object, 'val_star_rating': 0        4.0
#  1        4.0
#  2        4.1
#  3        4.3
#  4        4.1
#  5        4.4
#  6        4.1
#  7        4.3
#  8        4.1
#  9        4.5
#  10       3.6
#  11       4.4
#  12       4.2
#  13       3.5
#  14       4.8
#  15       5.0
#  16       5.0
#  17       4.0
#  18       4.0
#  19       4.5
#  20       5.0
#  21       5.0
#  22       NaN
#  23       4.0
#  24       4.7
#  25       5.0
#  26       3.0
#  27       4.8
#  28       4.5
#  29       3.0
#          ...
#  12231    3.4
#  12232    4.6
#  12233    4.4
#  12234    4.4
#  12235    4.0
#  12236    4.1
#  12237    4.4
#  12238    4.4
#  12239    4.6
#  12240    4.0
#  12241    3.5
#  12242    4.8
#  12243    4.8
#  12244    4.8
#  12245    4.8
#  12246    4.4
#  12247    4.7
#  12248    4.6
#  12249    4.6
#  12250    4.5
#  12251    5.0
#  12252    4.5
#  12253    4.8
#  12254    3.6
#  12255    4.5
#  12256    4.2
#  12257    4.1
#  12258    4.5
#  12259    5.0
#  12260    4.8
#  Name: val_star_rating, Length: 12261, dtype: float64, 'country': 0        US
#  1        US
#  2        US
#  3        US
#  4        US
#  5        US
#  6        US
#  7        US
#  8        US
#  9        US
#  10       US
#  11       US
#  12       US
#  13       US
#  14       US
#  15       US
#  16       US
#  17       US
#  18       US
#  19       US
#  20       US
#  21       US
#  22       US
#  23       US
#  24       US
#  25       US
#  26       US
#  27       US
#  28       US
#  29       US
#           ..
#  12231    PT
#  12232    PT
#  12233    PT
#  12234    PT
#  12235    PT
#  12236    PT
#  12237    PT
#  12238    PT
#  12239    PT
#  12240    PT
#  12241    PT
#  12242    PT
#  12243    PT
#  12244    PT
#  12245    PT
#  12246    PT
#  12247    PT
#  12248    PT
#  12249    PT
#  12250    PT
#  12251    PT
#  12252    PT
#  12253    PT
#  12254    PT
#  12255    PT
#  12256    PT
#  12257    PT
#  12258    PT
#  12259    PT
#  12260    PT
#  Name: country, Length: 12261, dtype: object}

# %% [markdown]
# (i don't know how to remove this cell)

# %%
#Use tab completion to investigate at least 3 other methods under the df object. 
#Pull up their docstrings and investigate what they do.

# %% [markdown]
# # Pandas Series
#
# While the entire spreadsheet is called a **dataframe**, each individual column is known as a **series**. You can access a specific column of a pandas dataframe one of two ways:
#
# `df['col_name']`
#
# or
#
# ```df.col_name```
#
# First note that in `df['col_name']` we need 'quotations' around the column name. The quotations denote the column name is a **string**, python's built in variable type for storing text. This can alternatively be replaced with double quotes `df["col_name"]`. In general, anything in quotations is a string in python code. Occassionally, with very ill formatted column names with quotations in the names themselves, you may even need to wrap a name in triple quotes `df["""col_name"""]` . This will rarely happen in this particular context, but is also the general pattern for dealing with messy strings.
#
# Note that the second method, `df.col_name`, will only work if there are no spaces within the name of the column. Similarly to tab completion with the command line, this is a primary reason why programers use dashes (-) and underscores (_) in lieu of whitespace in their variable and file names. Also note that no quotations are used when using this format. (The column names have been stored as attributes to the DataFrame object!)

# %%
#Previewing Data

# %%
df.head(2) #preview your spreadsheet again; 2 keeps it a nice small preview
# Out:
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
#
#                 set_name  star_rating    theme_name  val_star_rating country
# 0  Bird Island Egg Heist          4.5  Angry Birds™              4.0      US
# 1     Piggy Plane Attack          5.0  Angry Birds™              4.0      US

# %%
df['ages'].head()
# Out:
# 0    6-12
# 1    6-12
# 2    6-12
# 3     12+
# 4     12+
# Name: ages, dtype: object

# %%
df.ages[:5] #Here we introduce another new syntax the list slice [:5] this limits us to the first 5 items
# Out:
# 0    6-12
# 1    6-12
# 2    6-12
# 3     12+
# 4     12+
# Name: ages, dtype: object

# %% [markdown]
# # List and Series Slices
# Above, we introduced an entirely new programming pattern called a slice.
# The syntax for a slice is `[start:end]`.
#
# You can also pass an additional third parameter `[start:end:count_by]` which will allow you to:
# count every other: `[start:end:2]`
# count backwards: `start:end:-1]`
# or potentially much more cryptic patterns, depending on what you pass.
#
# While we could have also used `df.State.head()`, slicing works for many more datatypes. This includes the previously mentioned *strings* as well as **lists** and other iterable objects. **Series**, the columns of the pandas DataFrame are similar to python's built in *lists*, but also have additional *methods* built in to them that we will continue to investigate.

# %%
df.piece_count.

# %% [markdown]
# # Common Series Methods
# Some very useful series methods include:
# * df.col_name.value_counts()
# * df.col_name.astype()
# * series.mean()     #Changing notation here: series refers to df.col_name (which is a series)!
# * series.median()
# * series.min()
# * series.max()
# * series.std()
# * series.unique()
# * series.nunique()
# * series.sample()
# * series.sort_values()
#
# There are also many more but this is a very good starting point.
# Start pulling up some docstrings and getting acquainted with reading them yourself before we go through a few of these methods together.

# %%
df.play_star_rating.value_counts? #Read the docstring and tinker! See how it works.
# Out:
#   File "<ipython-input-45-b034a89c317a>", line 1
#     df.play_star_rating.value_counts? #Read the docstring and tinker! See how it works.
#                                     ^
# SyntaxError: invalid syntax

# %%
#Keep tinkering!
df['play_star_rating'].value_counts()
# Out:
# 5.0    2219
# 4.5    1136
# 4.7     840
# 4.0     816
# 4.3     793
# 4.6     685
# 4.4     566
# 4.8     504
# 4.2     467
# 4.1     320
# 3.9     281
# 3.6     213
# 4.9     204
# 3.5     204
# 3.0     202
# 3.2     192
# 3.7     186
# 3.8     148
# 2.0     126
# 3.3     120
# 2.7      64
# 1.0      42
# 2.2      42
# 2.5      42
# 3.4      25
# 2.9      21
# 2.3      20
# 3.1       4
# 2.8       2
# 2.1       2
# Name: play_star_rating, dtype: int64

# %%
#Keep tinkering!
df.play_star_rating.value_counts(normalize = True)
# Out:
# 5.0    0.211615
# 4.5    0.108335
# 4.7    0.080107
# 4.0    0.077818
# 4.3    0.075625
# 4.6    0.065325
# 4.4    0.053977
# 4.8    0.048064
# 4.2    0.044536
# 4.1    0.030517
# 3.9    0.026798
# 3.6    0.020313
# 4.9    0.019455
# 3.5    0.019455
# 3.0    0.019264
# 3.2    0.018310
# 3.7    0.017738
# 3.8    0.014114
# 2.0    0.012016
# 3.3    0.011444
# 2.7    0.006103
# 1.0    0.004005
# 2.2    0.004005
# 2.5    0.004005
# 3.4    0.002384
# 2.9    0.002003
# 2.3    0.001907
# 3.1    0.000381
# 2.8    0.000191
# 2.1    0.000191
# Name: play_star_rating, dtype: float64

# %% [markdown]
# # Graphing
#
# Our bread and butter tool for graphing in python will be **matplotlib**.
# There are a number of other packages you can also check out for visualization later on such as plotly, folium, and bokeh to name a few, but matplotlib is an industry standard used widely. As with the pandas package, we must import  the matplotlib package to use its built in functions and methods. Rather then import the entire package however, we import only the piece we intend to use (hence the dot notation) and again alias this under the shorthand *plt*. Finally, the iPython magic command **% matplotlib inline** makes these graphs appear within our jupyter notebook.

# %%
#import a subset of the matplotlib package under the alias 'plt'
import matplotlib.pyplot as plt

#ipython magic command for displaying graphs within the notebook
# %matplotlib inline

# %%
to_graph = df['theme_name'].value_counts(normalize = True)[:10]
to_graph.plot(kind='barh')

# %% [markdown]
# # Adding labels
# The graph above is a good start, but we should be sure to add some labels! To do this we make successive calls to the `plt` package we imported. Some common methods you should be familiar with include:
# * plt.title()
# * plt.xlabel()
# * plt.ylabel()
# * plt.legend()
# * plt.xticks()
# * plt.yticks()

# %%
to_graph = df.theme_name.value_counts()[:5]
to_graph.plot(kind='barh') #lots of other optional parameters can be passed such as color
plt.title('Top 5 Lego Themes', fontsize=16) #fontsize is optional
plt.xlabel('Number of Lego Sets') #you could also pass in fontsize if you wanted here
plt.ylabel('Theme') #you could also rotate text if you wanted
# Out:
# Text(0,0.5,'Theme')

# %% [markdown]
# # Practice and Explore
#
# Take a minute to try chaining some of these methods together to create a few of your own visuals for practice. Some ideas can include making a scatter plot with `plt.scatter(x , y)` where you pass in two series (one as x and the other as y), plotting histograms with the `series.hist()` method, or creating simple bar graphs as shown above.

# %%
plt.scatter(df.play_star_rating, df.star_rating)

# %%
df.play_star_rating.hist()

# %%
#Your code here
